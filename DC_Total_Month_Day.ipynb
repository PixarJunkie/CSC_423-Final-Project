# %% [markdown]
# #  DC Total Bike Share (Month Aggregated)

# %%
# #Group dates
# bike_df.Date = pd.to_datetime(bike_df.Date)
# bike_df['Month'] = bike_df.Date.dt.month
# bike_df['Day'] = bike_df.Date.dt.day

# bike_df = bike_df.dropna(how = 'any')

# bike_df.drop(bike_df[['Date', 'DAILYSnowDepth','DAILYSnowDepth']], axis = 1, inplace = True)

# #Create stats dict for column stats
# f = {'Customer_sum': 'sum', 'Subscriber_sum': 'sum', 'Total_Count sum': 'sum', 'Season': 'mean', 'Holiday': 'mean', 'Duration_mean': 'mean', 'DAILYAverageDryBulbTemp': 'mean', 'DAILYDeptFromNormalAverageTemp': 'mean', 'DAILYAverageRelativeHumidity': 'mean', 'DAILYCoolingDegreeDays': 'mean', 'DAILYSunrise': 'mean', 'DAILYSunset': 'mean', 'DAILYAverageStationPressure': 'mean', 'DAILYAverageWindSpeed': 'mean', 'DAILYSustainedWindSpeed': 'mean', 'DAILYSustainedWindDirection': 'mean'}

# #Aggregate data by day
# bike_df = bike_df.groupby(['Month', 'Day']).agg(f) #Groupby day and apply
# bike_df.to_csv('DC_aggregated.csv')

# %% [markdown]
# **Import pacakges**

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas.io.data as web
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import datetime as dt
import statsmodels as sm
import seaborn as sns
import pylab
import pprint
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.graphics as smgraph
import scipy.stats as stats

from numpy import genfromtxt
from scipy.stats import multivariate_normal
from pandas.tools.plotting import scatter_matrix
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression, LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import mean_squared_error, f1_score
from math import sqrt

# %matplotlib inline
sns.set_palette("Set2", 10) #Set color scheme
sns.set_style("darkgrid") #Set style for axis
pd.set_option('display.max_rows', 500)

# %%
#Import data files
bike_df = pd.read_csv('DC_aggregated.csv')
model_df = bike_df.copy()

# %%
model_df.head()
# Out:
#    Month  Day  Customer_sum  Subscriber_sum  Total_Count sum  Season  Holiday  \
# 0      1    1           229            1691             1920       1        1
# 1      1    2           429            3466             3895       1        0
# 2      1    3           176            1920             2096       1        0
# 3      1    4           105            4336             4441       1        0
# 4      1    5            96            5313             5409       1        0
#
#    DAILYSunset  DAILYAverageDryBulbTemp  DAILYSustainedWindDirection  \
# 0       1658.0                39.333333                   233.333333
# 1       1659.0                41.000000                   300.000000
# 2       1700.0                40.500000                   200.000000
# 3       1700.0                36.666667                   263.333333
# 4       1701.0                32.500000                   155.000000
#
#    DAILYAverageRelativeHumidity  DAILYAverageStationPressure  \
# 0                     53.666667                    30.140000
# 1                     54.000000                    30.115000
# 2                     69.500000                    30.095000
# 3                     57.666667                    30.076667
# 4                     37.500000                    30.340000
#
#    DAILYDeptFromNormalAverageTemp  DAILYSunrise  Duration_mean  \
# 0                        2.933333         727.0      13.700154
# 1                        4.700000         727.0      11.552192
# 2                        4.300000         727.0      11.751971
# 3                        0.566667         727.0      14.673400
# 4                       -3.500000         727.0       9.947841
#
#    DAILYAverageWindSpeed  DAILYCoolingDegreeDays  DAILYSustainedWindSpeed  \
# 0               7.066667                     0.0                     16.0
# 1               4.550000                     0.0                     13.5
# 2               5.600000                     0.0                     18.5
# 3              12.033333                     0.0                     24.0
# 4              12.250000                     0.0                     28.0
#
#   Season_Name
# 0      Winter
# 1      Winter
# 2      Winter
# 3      Winter
# 4      Winter

# %%
#Season dummy
season_dummy = pd.get_dummies(model_df.Season_Name)
model_df = pd.concat([model_df, season_dummy], axis = 1)
model_df.drop(['Season_Name'], axis = 1, inplace = True)

#Drop NaN rows
model_df = model_df.dropna(how = 'any')

#Outlier adjust
# model_df = model_df[model_df['Total_Count sum'] > 5000]
#Chose to keep these points in the model as the are all from the winter season (below)

# %%
model_df[model_df['Total_Count sum'] < 5000]
# Out:
#      Month  Day  Customer_sum  Subscriber_sum  Total_Count sum  Season  \
# 0        1    1           229            1691             1920       1
# 1        1    2           429            3466             3895       1
# 2        1    3           176            1920             2096       1
# 3        1    4           105            4336             4441       1
# 7        1    8            97            3943             4040       1
# 8        1    9           103            3348             3451       1
# 9        1   10            88            2320             2408       1
# 10       1   11           141            3659             3800       1
# 11       1   12           197            4106             4303       1
# 16       1   17           310            3725             4035       1
# 17       1   18           337            3049             3386       1
# 30       2    1            23             219              242       1
# 31       2    2            34             367              401       1
# 32       2    3            16            1196             1212       1
# 33       2    4            30            1178             1208       1
# 34       2    5             7             502              509       1
# 35       2    7             5             730              735       1
# 36       2    8             4             296              300       1
# 37       2    9            15             323              338       1
# 38       2   10             9             873              882       1
# 39       2   11            30            1045             1075       1
# 40       2   12            24            1257             1281       1
# 41       2   13            40            1349             1389       1
# 42       2   14            40            1298             1338       1
# 43       2   15            78             650              728       1
# 44       2   16            83             447              530       1
# 45       2   17            11             464              475       1
# 46       2   18            55            1344             1399       1
# 47       2   19           139            2096             2235       1
# 48       2   20            21             984             1005       1
# 49       2   21            47            1331             1378       1
# 50       2   22           177             937             1114       1
# 51       2   23           105             684              789       1
# 52       2   24            33            1506             1539       1
# 53       2   25            53            1474             1527       1
# 54       2   26            23            1116             1139       1
# 55       2   27            30            1081             1111       1
# 56       3    1           122            3937             4059       2
# 115      4   30           186            1464             1650       2
# 321     11   27           323            3365             3688       4
# 322     11   28           816            3330             4146       4
# 347     12   24           374            3948             4322       1
# 348     12   25           863            1416             2279       1
#
#      Holiday  DAILYSunset  DAILYAverageDryBulbTemp  \
# 0          1  1658.000000                39.333333
# 1          0  1659.000000                41.000000
# 2          0  1700.000000                40.500000
# 3          0  1700.000000                36.666667
# 7          0  1704.000000                30.500000
# 8          0  1705.000000                38.333333
# 9          0  1706.000000                36.000000
# 10         0  1707.000000                38.000000
# 11         0  1708.000000                40.666667
# 16         0  1714.000000                36.333333
# 17         1  1715.000000                32.333333
# 30         0  1731.000000                40.000000
# 31         0  1732.000000                49.000000
# 32         0  1733.000000                42.000000
# 33         0  1734.000000                34.000000
# 34         0  1735.000000                38.000000
# 35         0  1738.000000                36.000000
# 36         0  1739.000000                33.000000
# 37         0  1740.000000                32.000000
# 38         0  1741.000000                30.000000
# 39         0  1742.000000                28.000000
# 40         0  1743.000000                25.000000
# 41         0  1744.000000                33.000000
# 42         0  1746.000000                42.000000
# 43         0  1747.000000                36.000000
# 44         0  1748.000000                32.000000
# 45         1  1749.000000                32.000000
# 46         0  1750.000000                44.000000
# 47         0  1751.000000                49.000000
# 48         0  1752.000000                46.000000
# 49         0  1753.000000                54.000000
# 50         0  1754.000000                49.000000
# 51         0  1755.000000                55.000000
# 52         0  1757.000000                41.000000
# 53         0  1758.000000                34.000000
# 54         0  1759.000000                32.000000
# 55         0  1800.000000                32.000000
# 56         0  1802.333333                38.333333
# 115        0  1901.000000                54.000000
# 321        1  1648.000000                44.666667
# 322        1  1647.000000                42.666667
# 347        0  1652.000000                53.333333
# 348        1  1652.333333                53.333333
#
#      DAILYSustainedWindDirection   ...    DAILYDeptFromNormalAverageTemp  \
# 0                     233.333333   ...                          2.933333
# 1                     300.000000   ...                          4.700000
# 2                     200.000000   ...                          4.300000
# 3                     263.333333   ...                          0.566667
# 7                     125.000000   ...                         -5.400000
# 8                     103.333333   ...                          2.533333
# 9                     196.666667   ...                          0.200000
# 10                    253.333333   ...                          2.200000
# 11                    323.333333   ...                          4.966667
# 16                    246.666667   ...                          0.633333
# 17                    266.666667   ...                         -3.466667
# 30                    170.000000   ...                          3.300000
# 31                     20.000000   ...                         12.200000
# 32                    340.000000   ...                          5.000000
# 33                     50.000000   ...                         -3.100000
# 34                    310.000000   ...                          0.800000
# 35                     10.000000   ...                         -1.500000
# 36                     10.000000   ...                         -4.700000
# 37                    170.000000   ...                         -5.800000
# 38                    360.000000   ...                         -8.000000
# 39                     10.000000   ...                        -10.200000
# 40                     20.000000   ...                        -13.300000
# 41                     20.000000   ...                         -5.500000
# 42                    290.000000   ...                          3.300000
# 43                    320.000000   ...                         -2.900000
# 44                    310.000000   ...                         -7.100000
# 45                    330.000000   ...                         -7.300000
# 46                    210.000000   ...                          4.500000
# 47                    300.000000   ...                          9.300000
# 48                    170.000000   ...                          6.000000
# 49                    330.000000   ...                         13.800000
# 50                    230.000000   ...                          8.600000
# 51                    360.000000   ...                         14.300000
# 52                    320.000000   ...                          0.100000
# 53                    340.000000   ...                         -7.200000
# 54                    340.000000   ...                         -9.400000
# 55                    340.000000   ...                         -9.700000
# 56                    200.000000   ...                         -3.866667
# 115                    60.000000   ...                         -7.300000
# 321                   280.000000   ...                         -0.833333
# 322                   216.666667   ...                         -2.433333
# 347                   210.000000   ...                         15.833333
# 348                   310.000000   ...                         15.933333
#
#      DAILYSunrise  Duration_mean  DAILYAverageWindSpeed  \
# 0      727.000000      13.700154               7.066667
# 1      727.000000      11.552192               4.550000
# 2      727.000000      11.751971               5.600000
# 3      727.000000      14.673400              12.033333
# 7      727.000000      10.313021               7.950000
# 8      727.000000      10.954655               7.100000
# 9      726.000000      10.607632               9.333333
# 10     726.000000      10.830762               6.900000
# 11     726.000000      11.871557               8.966667
# 16     724.000000      11.616401               7.233333
# 17     724.000000      12.061939              11.766667
# 30     714.000000      11.359504               3.200000
# 31     713.000000      11.925187               3.600000
# 32     712.000000      12.179043              13.200000
# 33     711.000000      10.999172               6.200000
# 34     710.000000      10.660118              10.200000
# 35     708.000000      11.127891               6.800000
# 36     707.000000      14.006667               4.200000
# 37     706.000000      14.405325               4.500000
# 38     704.000000      14.112245              11.800000
# 39     703.000000      11.942326               8.200000
# 40     702.000000      13.042935               9.800000
# 41     701.000000      11.514759              17.100000
# 42     700.000000      11.056801               7.300000
# 43     659.000000      11.085165              13.400000
# 44     657.000000      14.707547               7.500000
# 45     656.000000      11.842105               7.200000
# 46     655.000000      13.120086               8.000000
# 47     653.000000      11.561521               8.700000
# 48     652.000000      11.736318               3.700000
# 49     651.000000      12.290276               4.800000
# 50     649.000000      13.109515               8.800000
# 51     648.000000      11.774398               8.500000
# 52     647.000000      10.064327              13.300000
# 53     645.000000      10.970530               5.100000
# 54     644.000000       9.213345               8.800000
# 55     642.000000       9.037804              16.000000
# 56     639.333333      10.575921               6.266667
# 115    510.000000      13.560000               6.000000
# 321    704.000000      11.176893               8.800000
# 322    705.000000      14.111666               7.066667
# 347    725.000000      11.291683               6.500000
# 348    725.000000      18.398448               6.433333
#
#      DAILYCoolingDegreeDays  DAILYSustainedWindSpeed  Fall  Spring  Summer  \
# 0                  0.000000                16.000000   0.0     0.0     0.0
# 1                  0.000000                13.500000   0.0     0.0     0.0
# 2                  0.000000                18.500000   0.0     0.0     0.0
# 3                  0.000000                24.000000   0.0     0.0     0.0
# 7                  0.000000                16.500000   0.0     0.0     0.0
# 8                  0.000000                17.000000   0.0     0.0     0.0
# 9                  0.000000                19.666667   0.0     0.0     0.0
# 10                 0.000000                18.666667   0.0     0.0     0.0
# 11                 0.000000                21.666667   0.0     0.0     0.0
# 16                 0.000000                16.000000   0.0     0.0     0.0
# 17                 0.000000                26.000000   0.0     0.0     0.0
# 30                 0.000000                15.000000   0.0     0.0     0.0
# 31                 0.000000                15.000000   0.0     0.0     0.0
# 32                 0.000000                20.000000   0.0     0.0     0.0
# 33                 0.000000                12.000000   0.0     0.0     0.0
# 34                 0.000000                30.000000   0.0     0.0     0.0
# 35                 0.000000                13.000000   0.0     0.0     0.0
# 36                 0.000000                13.000000   0.0     0.0     0.0
# 37                 0.000000                14.000000   0.0     0.0     0.0
# 38                 0.000000                23.000000   0.0     0.0     0.0
# 39                 0.000000                16.000000   0.0     0.0     0.0
# 40                 0.000000                18.000000   0.0     0.0     0.0
# 41                 0.000000                26.000000   0.0     0.0     0.0
# 42                 0.000000                26.000000   0.0     0.0     0.0
# 43                 0.000000                30.000000   0.0     0.0     0.0
# 44                 0.000000                18.000000   0.0     0.0     0.0
# 45                 0.000000                17.000000   0.0     0.0     0.0
# 46                 0.000000                20.000000   0.0     0.0     0.0
# 47                 0.000000                23.000000   0.0     0.0     0.0
# 48                 0.000000                17.000000   0.0     0.0     0.0
# 49                 0.000000                32.000000   0.0     0.0     0.0
# 50                 0.000000                20.000000   0.0     0.0     0.0
# 51                 0.000000                23.000000   0.0     0.0     0.0
# 52                 0.000000                26.000000   0.0     0.0     0.0
# 53                 0.000000                13.000000   0.0     0.0     0.0
# 54                 0.000000                23.000000   0.0     0.0     0.0
# 55                 0.000000                33.000000   0.0     0.0     0.0
# 56                 0.000000                16.000000   0.0     1.0     0.0
# 115                0.000000                13.000000   0.0     1.0     0.0
# 321                0.000000                21.333333   1.0     0.0     0.0
# 322                0.000000                19.333333   1.0     0.0     0.0
# 347                0.333333                17.333333   0.0     0.0     0.0
# 348                0.000000                23.000000   0.0     0.0     0.0
#
#      Winter
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 7       1.0
# 8       1.0
# 9       1.0
# 10      1.0
# 11      1.0
# 16      1.0
# 17      1.0
# 30      1.0
# 31      1.0
# 32      1.0
# 33      1.0
# 34      1.0
# 35      1.0
# 36      1.0
# 37      1.0
# 38      1.0
# 39      1.0
# 40      1.0
# 41      1.0
# 42      1.0
# 43      1.0
# 44      1.0
# 45      1.0
# 46      1.0
# 47      1.0
# 48      1.0
# 49      1.0
# 50      1.0
# 51      1.0
# 52      1.0
# 53      1.0
# 54      1.0
# 55      1.0
# 56      0.0
# 115     0.0
# 321     0.0
# 322     0.0
# 347     1.0
# 348     1.0
#
# [43 rows x 22 columns]

# %%
#Create dependent variable
y = model_df['Total_Count sum']

#Create independent variables
X = model_df.ix[:,'Holiday': 'Winter']

#Final model variables to drop (In order of highest p-value > .05)
X.drop(['DAILYSustainedWindDirection', 'DAILYAverageStationPressure', 'DAILYSunset', 'DAILYCoolingDegreeDays', 'DAILYAverageWindSpeed', 'DAILYSustainedWindSpeed'], axis = 1, inplace = True)
#  'Winter','Spring', 'Summer', 'Fall', 'Holiday'

# %% [markdown]
# # Data Set Decriptive Stats

# %%
model_df.describe()
# Out:
#             Month         Day  Customer_sum  Subscriber_sum  Total_Count sum  \
# count  354.000000  354.000000    354.000000      354.000000       354.000000
# mean     6.539548   15.330508   7689.115819    17890.985876     25580.101695
# std      3.444397    8.565748   7775.905529    10647.660496     17499.199475
# min      1.000000    1.000000      4.000000      219.000000       242.000000
# 25%      4.000000    8.000000    635.250000     8638.750000      9415.000000
# 50%      7.000000   15.000000   4689.500000    17574.000000     23747.500000
# 75%      9.750000   23.000000  13586.750000    27758.500000     43157.750000
# max     12.000000   30.000000  41421.000000    37494.000000     60785.000000
#
#            Season     Holiday  DAILYSunset  DAILYAverageDryBulbTemp  \
# count  354.000000  354.000000   354.000000               354.000000
# mean     2.511299    0.042373  1803.289783                59.734228
# std      1.114487    0.201724    99.204148                16.379841
# min      1.000000    0.000000  1646.000000                25.000000
# 25%      2.000000    0.000000  1718.750000                46.000000
# 50%      3.000000    0.000000  1816.916666                60.333333
# 75%      3.750000    0.000000  1909.187500                76.500000
# max      4.000000    1.000000  1937.000000                84.000000
#
#        DAILYSustainedWindDirection     ...      \
# count                   354.000000     ...
# mean                    214.781073     ...
# std                      71.348700     ...
# min                      10.000000     ...
# 25%                     173.333333     ...
# 50%                     215.833333     ...
# 75%                     266.666667     ...
# max                     360.000000     ...
#
#        DAILYDeptFromNormalAverageTemp  DAILYSunrise  Duration_mean  \
# count                      354.000000    354.000000     354.000000
# mean                         1.439878    583.179143      15.391224
# std                          4.635517     96.491973       3.710030
# min                        -13.300000    442.000000       9.037804
# 25%                         -0.991667    509.500000      12.022725
# 50%                          1.516667    577.625000      15.045446
# 75%                          4.112500    654.750000      18.400064
# max                         18.333333    727.000000      30.281049
#
#        DAILYAverageWindSpeed  DAILYCoolingDegreeDays  DAILYSustainedWindSpeed  \
# count             354.000000              354.000000               354.000000
# mean                8.272905                4.950565                18.954802
# std                 2.109266                6.378695                 3.948450
# min                 3.200000                0.000000                10.333333
# 25%                 6.900000                0.000000                16.000000
# 50%                 8.000000                0.666667                18.333333
# 75%                 9.525000               11.500000                21.333333
# max                17.100000               19.000000                33.000000
#
#              Fall      Spring      Summer      Winter
# count  354.000000  354.000000  354.000000  354.000000
# mean     0.251412    0.254237    0.251412    0.242938
# std      0.434439    0.436048    0.434439    0.429465
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000
# 75%      0.750000    1.000000    0.750000    0.000000
# max      1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# # Dependent Variable Distributions

# %%
#Count over time
plt.scatter(model_df.Month, model_df['Total_Count sum'])
plt.title('Dependent Over Time')

# %%
#Dependent distributions
ax = sns.distplot(model_df['Total_Count sum'], kde = False, rug = False, norm_hist = True)
plt.title('Total Count Distribution')
plt.xlabel('Total Count Sum')
ax.set_ylabel('Density')
plt.show()

# %%
#Correlation Heatmap
corr = model_df.corr()
sns.heatmap(corr)

# %%
#Correlation Values List
corr = pd.DataFrame(model_df.corr())
corr.dropna(how='any')

#Dropped (Based on correlation and heatmap > .90): 
# DAILYMaximumDryBulbTemp DAILYMinimumDryBulbTemp (Kept average)
# DAILYAverageSeaLevelPressure (Lower corr to dependent since redundant)
# DAILYPeakWindSpeed PeakWindDirection (Kept Average)
# DAILYAverageDewPointTemp DAILYAverageWetBulbTemp (Lower corr to dependent since redundant)
# Out:
#                                    Month       Day  Customer_sum  \
# Month                           1.000000  0.008053      0.190812
# Day                             0.008053  1.000000      0.001784
# Customer_sum                    0.190812  0.001784      1.000000
# Subscriber_sum                  0.390267  0.016541      0.799470
# Total_Count sum                 0.322253  0.010857      0.930808
# Season                          0.572915  0.005394      0.470203
# Holiday                         0.040391  0.000069      0.001406
# DAILYSunset                    -0.293529 -0.023702      0.700408
# DAILYAverageDryBulbTemp         0.320513  0.002203      0.838952
# DAILYSustainedWindDirection     0.012240  0.087822     -0.116485
# DAILYAverageRelativeHumidity    0.328017 -0.079964      0.166160
# DAILYAverageStationPressure     0.126178 -0.043410     -0.211141
# DAILYDeptFromNormalAverageTemp  0.274100 -0.019938      0.062319
# DAILYSunrise                    0.033283 -0.003640     -0.739762
# Duration_mean                   0.111175 -0.028287      0.924200
# DAILYAverageWindSpeed          -0.144633  0.077427     -0.233239
# DAILYCoolingDegreeDays          0.150302 -0.004561      0.829442
# DAILYSustainedWindSpeed        -0.232746  0.024321     -0.225433
# Fall                            0.581157  0.000445     -0.011196
# Spring                         -0.431099  0.011570     -0.153012
# Summer                          0.079475  0.000445      0.696700
# Winter                         -0.230576 -0.012647     -0.538087
#
#                                 Subscriber_sum  Total_Count sum    Season  \
# Month                                 0.390267         0.322253  0.572915
# Day                                   0.016541         0.010857  0.005394
# Customer_sum                          0.799470         0.930808  0.470203
# Subscriber_sum                        1.000000         0.963716  0.671892
# Total_Count sum                       0.963716         1.000000  0.617762
# Season                                0.671892         0.617762  1.000000
# Holiday                              -0.141950        -0.085747  0.004165
# DAILYSunset                           0.606547         0.680295  0.166746
# DAILYAverageDryBulbTemp               0.897356         0.918806  0.598074
# DAILYSustainedWindDirection          -0.126705        -0.128857 -0.072274
# DAILYAverageRelativeHumidity          0.251111         0.226626  0.179070
# DAILYAverageStationPressure          -0.257359        -0.250416 -0.069072
# DAILYDeptFromNormalAverageTemp        0.138084         0.111711  0.028842
# DAILYSunrise                         -0.719392        -0.766444 -0.390468
# Duration_mean                         0.729754         0.854705  0.432993
# DAILYAverageWindSpeed                -0.207177        -0.229702 -0.097386
# DAILYCoolingDegreeDays                0.780226         0.843309  0.395116
# DAILYSustainedWindSpeed              -0.254077        -0.254770 -0.183355
# Fall                                  0.222043         0.130130  0.775209
# Spring                               -0.187204        -0.181899 -0.268246
# Summer                                0.622703         0.688477  0.254480
# Winter                               -0.664456        -0.643402 -0.769257
#
#                                  Holiday  DAILYSunset  \
# Month                           0.040391    -0.293529
# Day                             0.000069    -0.023702
# Customer_sum                    0.001406     0.700408
# Subscriber_sum                 -0.141950     0.606547
# Total_Count sum                -0.085747     0.680295
# Season                          0.004165     0.166746
# Holiday                         1.000000    -0.166193
# DAILYSunset                    -0.166193     1.000000
# DAILYAverageDryBulbTemp        -0.106395     0.738468
# DAILYSustainedWindDirection     0.079213    -0.124238
# DAILYAverageRelativeHumidity    0.006838     0.047233
# DAILYAverageStationPressure     0.108153    -0.387590
# DAILYDeptFromNormalAverageTemp  0.001571    -0.025886
# DAILYSunrise                    0.156281    -0.935568
# Duration_mean                   0.012292     0.767419
# DAILYAverageWindSpeed          -0.049226    -0.102074
# DAILYCoolingDegreeDays         -0.077074     0.719380
# DAILYSustainedWindSpeed        -0.014483    -0.023317
# Fall                            0.104372    -0.405510
# Spring                         -0.122819     0.334474
# Summer                         -0.089579     0.654289
# Winter                          0.109737    -0.591262
#
#                                 DAILYAverageDryBulbTemp  \
# Month                                          0.320513
# Day                                            0.002203
# Customer_sum                                   0.838952
# Subscriber_sum                                 0.897356
# Total_Count sum                                0.918806
# Season                                         0.598074
# Holiday                                       -0.106395
# DAILYSunset                                    0.738468
# DAILYAverageDryBulbTemp                        1.000000
# DAILYSustainedWindDirection                   -0.078154
# DAILYAverageRelativeHumidity                   0.293433
# DAILYAverageStationPressure                   -0.373159
# DAILYDeptFromNormalAverageTemp                 0.348882
# DAILYSunrise                                  -0.844660
# Duration_mean                                  0.834706
# DAILYAverageWindSpeed                         -0.236236
# DAILYCoolingDegreeDays                         0.860533
# DAILYSustainedWindSpeed                       -0.183120
# Fall                                           0.080012
# Spring                                        -0.077903
# Summer                                         0.686211
# Winter                                        -0.696001
#
#                                 DAILYSustainedWindDirection    ...     \
# Month                                              0.012240    ...
# Day                                                0.087822    ...
# Customer_sum                                      -0.116485    ...
# Subscriber_sum                                    -0.126705    ...
# Total_Count sum                                   -0.128857    ...
# Season                                            -0.072274    ...
# Holiday                                            0.079213    ...
# DAILYSunset                                       -0.124238    ...
# DAILYAverageDryBulbTemp                           -0.078154    ...
# DAILYSustainedWindDirection                        1.000000    ...
# DAILYAverageRelativeHumidity                      -0.175179    ...
# DAILYAverageStationPressure                       -0.283578    ...
# DAILYDeptFromNormalAverageTemp                     0.142416    ...
# DAILYSunrise                                       0.106164    ...
# Duration_mean                                     -0.108533    ...
# DAILYAverageWindSpeed                              0.270908    ...
# DAILYCoolingDegreeDays                            -0.046458    ...
# DAILYSustainedWindSpeed                            0.426135    ...
# Fall                                              -0.023581    ...
# Spring                                            -0.084405    ...
# Summer                                            -0.014975    ...
# Winter                                             0.124700    ...
#
#                                 DAILYDeptFromNormalAverageTemp  DAILYSunrise  \
# Month                                                 0.274100      0.033283
# Day                                                  -0.019938     -0.003640
# Customer_sum                                          0.062319     -0.739762
# Subscriber_sum                                        0.138084     -0.719392
# Total_Count sum                                       0.111711     -0.766444
# Season                                                0.028842     -0.390468
# Holiday                                               0.001571      0.156281
# DAILYSunset                                          -0.025886     -0.935568
# DAILYAverageDryBulbTemp                               0.348882     -0.844660
# DAILYSustainedWindDirection                           0.142416      0.106164
# DAILYAverageRelativeHumidity                          0.286013     -0.111495
# DAILYAverageStationPressure                          -0.277600      0.351308
# DAILYDeptFromNormalAverageTemp                        1.000000     -0.038878
# DAILYSunrise                                         -0.038878      1.000000
# Duration_mean                                         0.096530     -0.802531
# DAILYAverageWindSpeed                                -0.173785      0.116048
# DAILYCoolingDegreeDays                                0.158105     -0.718468
# DAILYSustainedWindSpeed                               0.014096      0.057748
# Fall                                                  0.040490      0.174186
# Spring                                               -0.035349     -0.280196
# Summer                                               -0.006001     -0.621505
# Winter                                                0.001002      0.736992
#
#                                 Duration_mean  DAILYAverageWindSpeed  \
# Month                                0.111175              -0.144633
# Day                                 -0.028287               0.077427
# Customer_sum                         0.924200              -0.233239
# Subscriber_sum                       0.729754              -0.207177
# Total_Count sum                      0.854705              -0.229702
# Season                               0.432993              -0.097386
# Holiday                              0.012292              -0.049226
# DAILYSunset                          0.767419              -0.102074
# DAILYAverageDryBulbTemp              0.834706              -0.236236
# DAILYSustainedWindDirection         -0.108533               0.270908
# DAILYAverageRelativeHumidity         0.149117              -0.237485
# DAILYAverageStationPressure         -0.216994              -0.300888
# DAILYDeptFromNormalAverageTemp       0.096530              -0.173785
# DAILYSunrise                        -0.802531               0.116048
# Duration_mean                        1.000000              -0.231760
# DAILYAverageWindSpeed               -0.231760               1.000000
# DAILYCoolingDegreeDays               0.786242              -0.226776
# DAILYSustainedWindSpeed             -0.199489               0.769883
# Fall                                -0.078340              -0.006431
# Spring                               0.000579               0.140570
# Summer                               0.672608              -0.185813
# Winter                              -0.601739               0.051747
#
#                                 DAILYCoolingDegreeDays  \
# Month                                         0.150302
# Day                                          -0.004561
# Customer_sum                                  0.829442
# Subscriber_sum                                0.780226
# Total_Count sum                               0.843309
# Season                                        0.395116
# Holiday                                      -0.077074
# DAILYSunset                                   0.719380
# DAILYAverageDryBulbTemp                       0.860533
# DAILYSustainedWindDirection                  -0.046458
# DAILYAverageRelativeHumidity                  0.203767
# DAILYAverageStationPressure                  -0.305737
# DAILYDeptFromNormalAverageTemp                0.158105
# DAILYSunrise                                 -0.718468
# Duration_mean                                 0.786242
# DAILYAverageWindSpeed                        -0.226776
# DAILYCoolingDegreeDays                        1.000000
# DAILYSustainedWindSpeed                      -0.171169
# Fall                                         -0.127971
# Spring                                       -0.270802
# Summer                                        0.834664
# Winter                                       -0.439925
#
#                                 DAILYSustainedWindSpeed      Fall    Spring  \
# Month                                         -0.232746  0.581157 -0.431099
# Day                                            0.024321  0.000445  0.011570
# Customer_sum                                  -0.225433 -0.011196 -0.153012
# Subscriber_sum                                -0.254077  0.222043 -0.187204
# Total_Count sum                               -0.254770  0.130130 -0.181899
# Season                                        -0.183355  0.775209 -0.268246
# Holiday                                       -0.014483  0.104372 -0.122819
# DAILYSunset                                   -0.023317 -0.405510  0.334474
# DAILYAverageDryBulbTemp                       -0.183120  0.080012 -0.077903
# DAILYSustainedWindDirection                    0.426135 -0.023581 -0.084405
# DAILYAverageRelativeHumidity                  -0.238965  0.125825 -0.202101
# DAILYAverageStationPressure                   -0.410097  0.144638 -0.038909
# DAILYDeptFromNormalAverageTemp                 0.014096  0.040490 -0.035349
# DAILYSunrise                                   0.057748  0.174186 -0.280196
# Duration_mean                                 -0.199489 -0.078340  0.000579
# DAILYAverageWindSpeed                          0.769883 -0.006431  0.140570
# DAILYCoolingDegreeDays                        -0.171169 -0.127971 -0.270802
# DAILYSustainedWindSpeed                        1.000000 -0.132080  0.165746
# Fall                                          -0.132080  1.000000 -0.338370
# Spring                                         0.165746 -0.338370  1.000000
# Summer                                        -0.120244 -0.335849 -0.338370
# Winter                                         0.086961 -0.328287 -0.330751
#
#                                   Summer    Winter
# Month                           0.079475 -0.230576
# Day                             0.000445 -0.012647
# Customer_sum                    0.696700 -0.538087
# Subscriber_sum                  0.622703 -0.664456
# Total_Count sum                 0.688477 -0.643402
# Season                          0.254480 -0.769257
# Holiday                        -0.089579  0.109737
# DAILYSunset                     0.654289 -0.591262
# DAILYAverageDryBulbTemp         0.686211 -0.696001
# DAILYSustainedWindDirection    -0.014975  0.124700
# DAILYAverageRelativeHumidity    0.142375 -0.066108
# DAILYAverageStationPressure    -0.286027  0.182532
# DAILYDeptFromNormalAverageTemp -0.006001  0.001002
# DAILYSunrise                   -0.621505  0.736992
# Duration_mean                   0.672608 -0.601739
# DAILYAverageWindSpeed          -0.185813  0.051747
# DAILYCoolingDegreeDays          0.834664 -0.439925
# DAILYSustainedWindSpeed        -0.120244  0.086961
# Fall                           -0.335849 -0.328287
# Spring                         -0.338370 -0.330751
# Summer                          1.000000 -0.328287
# Winter                         -0.328287  1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# # Categorical Boxplots

# %%
#Season df for labels
seasons_df = model_df[['Total_Count sum', 'Season']]

#Seasons Boxplots
ax = sns.boxplot(y, groupby = bike_df.Season_Name)
plt.title('Season Box Plot')
ax.set_ylabel('Total Count Sum')
plt.xlabel('Season')
plt.show()

# %%
#Holiday Boxplots
ax = sns.boxplot(y, groupby = model_df.Holiday)
plt.title('Holiday Box Plot')
ax.set_ylabel('Total Count Sum')
plt.xlabel('Holiday (1-True, 0-False)')
plt.show()

# %% [markdown]
# # Training and Test Sets

# %%
#Training/Test set from sklearn
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 7777)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (283, 10)
# (283,)
# (71, 10)
# (71,)

# %% [markdown]
# # Linear Regression Model

# %%
#Linear Regression Model
lm = smf.OLS(y_train.astype(float), X_train.astype(float))
results = lm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Total_Count sum   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     437.0
# Date:                Sun, 04 Jun 2017   Prob (F-statistic):          1.63e-156
# Time:                        10:45:55   Log-Likelihood:                -2777.9
# No. Observations:                 283   AIC:                             5576.
# Df Residuals:                     273   BIC:                             5612.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------
# Holiday                        -2808.6718   1434.999     -1.957      0.051     -5633.743    16.399
# DAILYAverageDryBulbTemp         1457.0198     82.286     17.707      0.000      1295.023  1619.016
# DAILYAverageRelativeHumidity     -59.7569     32.034     -1.865      0.063      -122.821     3.307
# DAILYDeptFromNormalAverageTemp -1330.2740    104.411    -12.741      0.000     -1535.827 -1124.721
# DAILYSunrise                      79.4194     10.575      7.510      0.000        58.600   100.239
# Duration_mean                   1109.7468    157.444      7.049      0.000       799.788  1419.706
# Fall                           -1.197e+05   1.05e+04    -11.410      0.000      -1.4e+05  -9.9e+04
# Spring                         -1.189e+05   9479.381    -12.538      0.000     -1.38e+05    -1e+05
# Summer                         -1.231e+05   1.04e+04    -11.801      0.000     -1.44e+05 -1.03e+05
# Winter                         -1.153e+05   9983.247    -11.549      0.000     -1.35e+05 -9.56e+04
# ==============================================================================
# Omnibus:                       28.479   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.932
# Skew:                          -0.576   Prob(JB):                     8.71e-12
# Kurtosis:                       4.730   Cond. No.                     4.50e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Residual Analysis

# %%
#Calculate residuals
predicted = results.fittedvalues
res = y_train - predicted

# %%
#Residual distribution
ax = sns.distplot(res, kde = False, rug = False, norm_hist = True)
plt.title('Residuals Distribution Plot')
plt.xlabel('Residuals')
plt.show()

# %%
#Normal Residuals Plot
ax = sns.residplot(res, predicted)
plt.xlabel('Predicted')
ax.set_ylabel('Standardized Residuals')
plt.title('Normal Residuals Plot')
plt.show()

# %%
#Probability Plot
measurements = np.random.normal(loc = 20, scale = 5, size=100)   
stats.probplot(res, dist="norm", plot=pylab)
pylab.show()

# %%
# Feature Importance
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
# fit an Extra Trees model to the data (fits n randomized decision trees on subsets of the data)
#uses averaging
model = ExtraTreesClassifier()
model.fit(X, y)
# display the relative importance of each attribute
print(model.feature_importances_)
# Out:
# [ 0.01416431  0.1898017   0.19263456  0.18951841  0.18866856  0.20453258
#   0.00623229  0.00623229  0.00311615  0.00509915]

# %%
# Plot feature importance
feature_importance = model.feature_importances_
# normalize importances relative to max importance
print(list(feature_importance))
feature_importance = 100.0 * (feature_importance / feature_importance.max()) #Normalize
feature_importance = feature_importance[0:50]
sorted_idx = np.argsort(feature_importance)[::-1][:50]
pos = np.arange(sorted_idx.shape[0]) + .5
plt.figure(figsize=(20,4))
plt.subplot(1, 2, 2)
plt.bar(pos, feature_importance[sorted_idx], align='center')
plt.xticks(pos, X.columns[sorted_idx], rotation='vertical')
plt.ylabel('Relative Importance')
plt.title('Variable Importance')

plt.show()
# Out:
# [0.014164305949008499, 0.18980169971671385, 0.1926345609065156, 0.18951841359773372, 0.18866855524079318, 0.20453257790368271, 0.0062322946175637391, 0.0062322946175637399, 0.0031161473087818691, 0.0050991501416430595]

# %%
#Average Duration
duration = (model_df.groupby(model_df.Month, as_index = False).mean().groupby(model_df.Duration_mean).mean())
plt.bar(duration.Month, duration.Duration_mean)
plt.title('Mean Duration')

# %%
#Average Daily Sunrise
sunrise = (model_df.groupby(model_df.Month, as_index = False).mean().groupby(model_df.DAILYSunrise).mean())

plot = plt.bar(duration.Month, duration.DAILYSunrise)
plt.title('Daily Sunrise')

# %%
#Average Wind Speed
windspeed = (model_df.groupby(model_df.Month, as_index = False).mean().groupby(model_df.DAILYSustainedWindSpeed).mean())
plt.bar(windspeed.Month, windspeed.DAILYSustainedWindSpeed)
plt.title('Average Wind Speed')

# %%
#Average Departure
departure = (model_df.groupby(model_df.Month, as_index = False).mean().groupby(model_df.DAILYDeptFromNormalAverageTemp).mean())
plt.bar(departure.Month, departure.DAILYDeptFromNormalAverageTemp)
plt.title('Mean Departure')

# %% [markdown]
# # Predictions

# %%
#Prediction on test set, plot predicted vs. actuals
preds = results.predict(X_test.astype(float))
plt.scatter(y_test, preds)
plt.title('Predicted vs. Actuals')
plt.xlabel('Actuals')
plt.ylabel('Predicted')
rms = sqrt(mean_squared_error(y_test, preds)) #RMSE
print('Root Mean Square Error: ' + str(rms))
# Out:
# Root Mean Square Error: 4797.441593728506
